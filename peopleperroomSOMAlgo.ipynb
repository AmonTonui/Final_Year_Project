# %% [markdown]
# <a href="https://colab.research.google.com/github/AmonTonui/Final_Year_Project/blob/main/peopleperroomSOMAlgo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
  # Install Intrasom
  # !pip install minisom

LOCAL_DEV = True
if LOCAL_DEV:
    sys.path.insert(0, '../')
    # %load_ext autoreload
# Out:
# Collecting minisom
#   Downloading minisom-2.3.5.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: minisom
#   Building wheel for minisom (setup.py) ... done
#   Created wheel for minisom: filename=MiniSom-2.3.5-py3-none-any.whl size=12031 sha256=0795870281d1d2730556af66500aaf87fafdc4aebd620aa8019e16f0da388fe4
#   Stored in directory: /root/.cache/pip/wheels/19/db/95/5e53bc2b88a328217fdf9f2886cafbe86b0df274f4b601f572
# Successfully built minisom
# Installing collected packages: minisom
# Successfully installed minisom-2.3.5

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from minisom import MiniSom
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from matplotlib.lines import Line2D
import numpy as np
from sklearn.model_selection import train_test_split


data = pd.read_csv("peopleperroomnormalized_with_winners_cleaned2024.csv")
filtered_data = data[data['Winning Party'].isin(['Labour', 'Conservative', 'Liberal Democrat'])]#Filtering the data to train and display conservative and labour
filtered_data = filtered_data.reset_index(drop=True)

# The party colour that i will use for plotting. It is not passed through the SOM
party_colors = {
    'Conservative': (0, 0, 1),    # Blue
    'Labour': (1, 0, 0),          # Red
    'Liberal Democrat': (0.98, 0.6, 0.1),  # Orange
    # 'Green': (0, 0.6, 0.3),         # Dark Green
    # 'The Brexit Party': (0.6, 0.2, 0.8) #light blue

}


#Data with Labels that I will use to map the result clusters
labeling_columns = ['Westminster Parliamentary constituencies', 'Winning Party', 'Winning Vote Share']
features = filtered_data.drop(columns=labeling_columns)

#Feature Scaling
# scaler = MinMaxScaler()
# normalized_features = scaler.fit_transform(data[features])

robust_scaler = RobustScaler()#Robust scaler used as it handles outliers better than min max scaler
normalized_features = robust_scaler.fit_transform(features)



normalized_df = pd.DataFrame(normalized_features, columns=features.columns)
normalized_df[labeling_columns] = filtered_data[labeling_columns]

print(normalized_df.head())
print(normalized_df.shape[0])
print(normalized_df.isnull().sum())
# Out:
#    Over 0.5 and up to 1.0 people per room  \
# 0                                0.865244
# 1                                0.258322
# 2                                0.954013
# 3                               -0.247704
# 4                               -0.901217
#
#    Over 1.0 and up to 1.5 people per room  Over 1.5 people per room  \
# 0                                0.949799                  0.550301
# 1                               -0.112459                 -0.255829
# 2                               -0.460397                 -0.397059
# 3                               -0.160817                 -0.248282
# 4                               -0.389648                 -0.385724
#
#    Up to and including 0.5 people per room  \
# 0                                -0.780952
# 1                                 0.088979
# 2                                -0.010611
# 3                                 0.311631
# 4                                 0.701555
#
#   Westminster Parliamentary constituencies Winning Party  Winning Vote Share
# 0                                aldershot        Labour            0.407136
# 1                       aldridgebrownhills  Conservative            0.388663
# 2                 altrincham and sale west        Labour            0.404221
# 3                             amber valley        Labour            0.370224
# 4                  arundel and south downs  Conservative            0.401918
# 363
# Over 0.5 and up to 1.0 people per room      0
# Over 1.0 and up to 1.5 people per room      0
# Over 1.5 people per room                    0
# Up to and including 0.5 people per room     0
# Westminster Parliamentary constituencies    0
# Winning Party                               0
# Winning Vote Share                          0
# dtype: int64

# %%
# import math
# Initialize and Train SOM
n_neurons = int(np.sqrt(5 * np.sqrt(normalized_features.shape[0])))
# n_neurons = int(math.ceil(5*np.sqrt(normalized_features.shape[0])))
m_neurons = n_neurons

som = MiniSom(n_neurons, m_neurons, normalized_features.shape[1], sigma=1.645, learning_rate=0.3584,
              neighborhood_function='gaussian', random_seed=0, topology='rectangular')


som.random_weights_init(normalized_features)#Used random so that everything within the dataset may not be suppressed unlike pca makes the dataset to be linear.

# Train the SOM
num_iterations = 2500#optimal number of iterations based on the iterations tuning.
som.train(normalized_features, num_iterations, verbose=True)

# Assign winning neurons (Best Matching Units - BMUs) for each data point
winning_neurons = [som.winner(x) for x in normalized_features]
normalized_df['Neuron Row'] = [wn[0] for wn in winning_neurons]
normalized_df['Neuron Col'] = [wn[1] for wn in winning_neurons]
# Out:
#  [ 2500 / 2500 ] 100% - 0:00:00 left
#  quantization error: 0.2248895075081065

# %%
def topographic_error(som, data):
    error_count = 0
    for x in data:
        bmu = som.winner(x)
        distances = np.linalg.norm(som.get_weights() - x, axis=2)
        second_bmu = np.unravel_index(np.argsort(distances.ravel())[1], distances.shape)

        if abs(bmu[0] - second_bmu[0]) > 1 or abs(bmu[1] - second_bmu[1]) > 1:
            error_count += 1
    return error_count / len(data)

te = topographic_error(som, normalized_features)
print(f"Topographic Error: {te}")
# Out:
# Topographic Error: 0.013774104683195593

# %%
#U*-Matrix plotting implementation(Combination of a density matrix and distance matrix)
from scipy.ndimage import median_filter

# This process was emulated from a cited paper within the report of the u*-matrix
u_matrix = som.distance_map()
#plotting the two dimensional grid
density_matrix = np.zeros((n_neurons, m_neurons))

for r, c in zip(normalized_df['Neuron Row'], normalized_df['Neuron Col']):
    density_matrix[r, c] += 1

# Normalize density values to avoid division errors
density_matrix = median_filter(density_matrix, size=3)

# Step 3: Compute the U*-Matrix
min_p = np.min(density_matrix)
mean_p = np.mean(density_matrix)

if mean_p - min_p == 0:
    scale_factor = np.ones_like(density_matrix)
else:
    scale_factor = (density_matrix - min_p) / (mean_p - min_p)
u_star_matrix = u_matrix * scale_factor


party_counts = (normalized_df
                .groupby(['Neuron Row', 'Neuron Col', 'Winning Party'])
                .size()
                .unstack(fill_value=0))

dominant = party_counts.idxmax(axis=1)
share    = party_counts.max(axis=1) / party_counts.sum(1)


labels_df = pd.concat([dominant.rename('major_party'),
                       share.rename('purity')], axis=1)
labels_df.to_csv('NeuronPurity.csv')

#plotting the two dimensional grid
plt.figure(figsize=(16, 12))
plt.title("U*-Matrix with Overlaid Winning Parties")
plt.imshow(u_star_matrix.T, cmap='coolwarm', origin='lower', vmin=0, vmax=1)
plt.colorbar(label="Neuron Distance (U*-Matrix)")

# Overlayying the winning parties on the grid

for (r, c), party in dominant.items():


    if party in party_colors:
        base_color = np.array(party_colors[party])

        plt.scatter(c,
                    r,
                    s=share.loc[r,c] * 200,
                    color=base_color,
                    alpha=0.7, edgecolors='k')

# Add legend
legend_elements = [Line2D([0], [0], color=color, label=party, markersize=10)
                   for party, color in party_colors.items()]
plt.legend(handles=legend_elements, loc='upper right', title="Winning Parties")
plt.xlabel("Neuron Column")
plt.ylabel("Neuron Row")
plt.show()

#The feature planes plotted so as to see how each constituency votes based on the feature category
for feature_name in features.columns:
    feature_index = features.columns.get_loc(feature_name)
    feature_plane = som.get_weights()[:, :, feature_index]

    plt.figure(figsize=(8, 6))
    plt.imshow(feature_plane, cmap='Greys', origin='lower', alpha=0.7)
    plt.colorbar(label=feature_name)
    plt.title(f"Feature Plane for {feature_name} with Winning Parties")
    plt.xlabel("Neuron Column")
    plt.ylabel("Neuron Row")

    # for index, row in normalized_df.iterrows():
    for (r, c), party in dominant.items():

        colour = np.array(party_colors[party])
        if party in party_colors:
          plt.scatter(c, r, color=colour, marker='o', s=20)

    plt.show()

# Neuron-Constituency Mapping for cluster analysis and understanding
neuron_constituency_map = {}
for index, row in normalized_df.iterrows():
    neuron = (row['Neuron Row'], row['Neuron Col'])
    constituency = row['Westminster Parliamentary constituencies']
    if neuron not in neuron_constituency_map:
        neuron_constituency_map[neuron] = []
    neuron_constituency_map[neuron].append(constituency)


# Print the constituencies mapped to each neuron
for neuron, constituencies in neuron_constituency_map.items():
    print(f"Neuron {neuron}: {constituencies}")





normalized_df['Neuron'] = list(zip(normalized_df['Neuron Row'], normalized_df['Neuron Col']))
# Party Distribution of the winning neurons with its vote share dataset for analysis
grouped = normalized_df.groupby("Neuron").agg({
    'Winning Party': lambda x: x.value_counts().to_dict(),
    'Winning Vote Share': 'mean',
}).rename(columns={
    'Winning Party': 'Party Distribution',
    'Winning Vote Share': 'Avg Vote Share',
})

print(grouped.head())


grouped.to_csv('neuron_party_distribution.csv')

from matplotlib import pyplot as plt

hit_map = np.zeros((som._weights.shape[0], som._weights.shape[1]))
for x in normalized_features:
    bmu = som.winner(x)
    hit_map[bmu] += 1

plt.imshow(hit_map.T, cmap='Blues', origin='lower')
plt.colorbar(label='Number of Constituencies')
plt.title('Neuron Occupancy Heatmap')
plt.xlabel('Neuron Column')
plt.ylabel('Neuron Row')
plt.show()
# Out:
# Neuron (6, 7): ['aldershot', 'birmingham selly oak', 'broxbourne', 'hertsmere', 'spelthorne']
# Neuron (1, 6): ['aldridgebrownhills', 'cannock chase', 'horsham', 'makerfield', 'mid sussex']
# Neuron (0, 8): ['altrincham and sale west', 'bath', 'exeter', 'filton and bradley stoke', 'leeds north west', 'york central']
# Neuron (2, 3): ['amber valley', 'chesham and amersham', 'newcastleunderlyme', 'north west hampshire', 'shipley', 'south cambridgeshire', 'surrey heath', 'witney']
# Neuron (1, 1): ['arundel and south downs', 'barrow and furness', 'bassetlaw', 'central suffolk and north ipswich', 'daventry', 'scarborough and whitby', 'south norfolk', 'staffordshire moorlands']
# Neuron (4, 6): ['ashford', 'nuneaton', 'telford']
# Neuron (6, 3): ['ashtonunderlyne', 'birmingham erdington', 'preston']
# Neuron (5, 5): ['aylesbury', 'basildon and billericay', 'sittingbourne and sheppey', 'stalybridge and hyde']
# Neuron (3, 6): ['banbury', 'faversham and mid kent', 'gloucester', 'poole']
# Neuron (8, 0): ['barking', 'ealing southall', 'east ham', 'feltham and heston', 'hayes and harlington', 'ilford south', 'poplar and limehouse']
# Neuron (4, 8): ['basingstoke', 'east worthing and shoreham', 'richmond park', 'stockport', 'stretford and urmston']
# Neuron (8, 6): ['battersea', 'tooting']
# Neuron (1, 4): ['beaconsfield', 'darlington', 'erewash', 'esher and walton', 'hartlepool', 'oxford west and abingdon', 'redcar', 'south northamptonshire', 'west lancashire']
# Neuron (5, 4): ['bedford', 'birmingham northfield', 'milton keynes north', 'northampton north']
# Neuron (8, 3): ['bermondsey and old southwark', 'enfield north', 'hackney south and shoreditch', 'ilford north']
# Neuron (0, 1): ['beverley and holderness', 'congleton', 'fylde', 'sleaford and north hykeham', 'stratfordonavon', 'tatton']
# Neuron (2, 0): ['bexhill and battle', 'central devon', 'forest of dean', 'north shropshire', 'south east cornwall', 'southport']
# Neuron (8, 7): ['bexleyheath and crayford', 'kingston and surbiton', 'wimbledon']
# Neuron (1, 2): ['birkenhead', 'carlisle', 'lichfield', 'maldon', 'middlesbrough south and east cleveland', 'north west leicestershire', 'stroud', 'tewkesbury']
# Neuron (5, 2): ['birmingham edgbaston', 'bury north', 'halifax', 'huddersfield']
# Neuron (7, 0): ['birmingham ladywood', 'bradford west', 'slough']
# Neuron (6, 0): ['birmingham yardley', 'bradford east', 'luton north', 'rochdale']
# Neuron (2, 1): ['bishop auckland', 'chichester', 'christchurch', 'harwich and north essex', 'mid norfolk', 'new forest east']
# Neuron (1, 3): ['blackpool south', 'cheltenham', 'chippenham', 'north durham', 'north east derbyshire', 'ribble valley', 'south derbyshire', 'south ribble']
# Neuron (4, 4): ['bognor regis and littlehampton', 'ipswich', 'woking']
# Neuron (2, 5): ['bolsover', 'braintree', 'gosport', 'loughborough', 'mansfield', 'scunthorpe', 'sunderland central', 'tamworth', 'westonsupermare']
# Neuron (5, 0): ['bolton north east', 'nottingham east', 'sheffield brightside and hillsborough']
# Neuron (3, 5): ['bolton west', 'derby north', 'east surrey', 'maidenhead', 'redditch', 'worcester', 'worthing west']
# Neuron (0, 6): ['bootle', 'easington', 'hazel grove', 'houghton and sunderland south', 'mid bedfordshire']
# Neuron (5, 8): ['bournemouth east', 'bristol north west', 'colchester', 'gillingham and rainham', 'rochester and strood']
# Neuron (7, 7): ['bournemouth west', 'dartford']
# Neuron (3, 8): ['bracknell', 'epsom and ewell']
# Neuron (6, 4): ['bradford south', 'northampton south', 'wycombe']
# Neuron (8, 2): ['brentford and isleworth', 'ealing north', 'erith and thamesmead', 'harrow west', 'mitcham and morden']
# Neuron (2, 6): ['brentwood and ongar', 'kettering', 'liverpool walton', 'rugby', 'windsor']
# Neuron (5, 7): ['bristol east', 'epping forest', 'portsmouth south']
# Neuron (7, 8): ['bristol south']
# Neuron (0, 3): ['bromsgrove', 'mid derbyshire', 'north east hampshire', 'rushcliffe', 'sheffield hallam']
# Neuron (0, 4): ['broxtowe', 'city of durham', 'newcastle upon tyne north', 'south west devon', 'sutton coldfield', 'thornbury and yate', 'tynemouth', 'warrington south', 'york outer']
# Neuron (5, 1): ['burnley', 'cities of london and westminster', 'hyndburn']
# Neuron (4, 5): ['bury south', 'eastbourne', 'leeds north east', 'lincoln', 'rossendale and darwen']
# Neuron (2, 4): ['calder valley', 'high peak', 'sevenoaks', 'south shields', 'st helens south and whiston', 'west suffolk']
# Neuron (4, 3): ['camborne and redruth', 'havant', 'sheffield heeley', 'stokeontrent north', 'stokeontrent south']
# Neuron (6, 6): ['cambridge', 'chelsea and fulham', 'ruislip northwood and pinner', 'sheffield central', 'southampton itchen']
# Neuron (2, 7): ['canterbury', 'liverpool wavertree']
# Neuron (7, 5): ['carshalton and wallington', 'crawley', 'southampton test', 'wolverhampton south east']
# Neuron (3, 7): ['castle point', 'liverpool riverside', 'plymouth sutton and devonport', 'reigate']
# Neuron (6, 8): ['chatham and aylesford', 'hemel hempstead', 'stevenage', 'welwyn hatfield', 'wythenshawe and sale east']
# Neuron (0, 7): ['cheadle', 'knowsley', 'rayleigh and wickford', 'wokingham']
# Neuron (2, 8): ['chelmsford', 'liverpool west derby', 'orpington', 'runnymede and weybridge']
# Neuron (3, 1): ['chesterfield', 'folkestone and hythe', 'north west norfolk', 'norwich north', 'south west norfolk', 'wyre forest']
# Neuron (8, 5): ['chingford and woodford green', 'dulwich and west norwood', 'islington south and finsbury', 'putney', 'watford']
# Neuron (7, 6): ['chipping barnet', 'nottingham south', 'romford', 'sutton and cheam']
# Neuron (4, 1): ['colne valley']
# Neuron (5, 6): ['coventry north west', 'coventry south', 'croydon south']
# Neuron (3, 2): ['crewe and nantwich', 'south holland and the deepings', 'yeovil']
# Neuron (7, 2): ['dagenham and rainham', 'greenwich and woolwich', 'holborn and st pancras']
# Neuron (6, 1): ['derby south', 'oldham east and saddleworth']
# Neuron (0, 0): ['derbyshire dales', 'gainsborough', 'hexham', 'north norfolk', 'suffolk coastal', 'thirsk and malton', 'west dorset', 'west worcestershire', 'westmorland and lonsdale']
# Neuron (3, 3): ['doncaster central', 'newbury', 'north east cambridgeshire', 'north west cambridgeshire', 'norwich south', 'stockton north', 'the wrekin']
# Neuron (1, 5): ['doncaster north', 'mid dorset and north poole', 'morecambe and lunesdale', 'north east hertfordshire', 'st helens north', 'truro and falmouth', 'warrington north', 'witham']
# Neuron (8, 4): ['ealing central and acton', 'oxford east', 'uxbridge and south ruislip']
# Neuron (2, 2): ['east hampshire', 'hereford and south herefordshire', 'huntingdon', 'lewes', 'newton abbot', 'north devon', 'romsey and southampton north', 'salisbury', 'south west wiltshire']
# Neuron (1, 8): ['eastleigh', 'hertford and stortford', 'warwick and leamington']
# Neuron (7, 3): ['finchley and golders green', 'leicester west', 'lewisham east']
# Neuron (0, 5): ['gedling', 'rother valley', 'south leicestershire', 'winchester']
# Neuron (6, 5): ['gravesham', 'hornchurch and upminster', 'wolverhampton north east']
# Neuron (1, 7): ['guildford', 'south west hertfordshire']
# Neuron (8, 1): ['hackney north and stoke newington', 'leicester east', 'tottenham', 'walthamstow']
# Neuron (7, 4): ['harlow', 'manchester central', 'thurrock']
# Neuron (0, 2): ['harrogate and knaresborough', 'kenilworth and southam', 'macclesfield', 'north somerset', 'penistone and stocksbridge', 'sefton central', 'stafford', 'wallasey', 'wirral west']
# Neuron (7, 1): ['harrow east', 'hendon', 'leyton and wanstead']
# Neuron (4, 2): ['hastings and rye']
# Neuron (4, 7): ['kingston upon hull east', 'plymouth moor view']
# Neuron (6, 2): ['leeds east', 'peterborough']
# Neuron (1, 0): ['louth and horncastle', 'new forest west', 'newark', 'north dorset', 'skipton and ripon', 'south suffolk']
# Neuron (8, 8): ['manchester withington', 'old bexley and sidcup', 'portsmouth north', 'st albans', 'twickenham']
# Neuron (3, 0): ['north cornwall', 'south dorset', 'st ives']
# Neuron (5, 3): ['rotherham', 'sheffield south east']
# Neuron (3, 4): ['st austell and newquay', 'stourbridge', 'torbay', 'tunbridge wells', 'wigan']
# Neuron (4, 0): ['stokeontrent central']
#                                        Party Distribution  Avg Vote Share
# Neuron
# (0, 0)  {'Labour': 3, 'Conservative': 3, 'Liberal Demo...        0.421252
# (0, 1)  {'Conservative': 4, 'Labour': 1, 'Liberal Demo...        0.373024
# (0, 2)  {'Labour': 7, 'Liberal Democrat': 1, 'Conserva...        0.454595
# (0, 3)  {'Labour': 3, 'Conservative': 1, 'Liberal Demo...        0.394939
# (0, 4)  {'Labour': 6, 'Conservative': 2, 'Liberal Demo...        0.436043

# %%
#Clusters identified
valley_cells = {(2,5), (1,5)}

valley_df = normalized_df[
    normalized_df.apply(
        lambda r: (r['Neuron Row'], r['Neuron Col']) in valley_cells,
        axis=1
    )
][[
    'Westminster Parliamentary constituencies',
    'Winning Party',
    'Winning Vote Share'
]]

valley_df.to_csv("valley_constituencies.csv", index=False)
display(valley_df.head())
# Out:
#     Westminster Parliamentary constituencies Winning Party  Winning Vote Share
# 32                                  bolsover        Labour            0.405265
# 42                                 braintree  Conservative            0.355185
# 94                           doncaster north        Labour            0.523547
# 124                                  gosport  Conservative            0.402692
# 178                             loughborough        Labour            0.408173

# %%
seat_counts  = valley_df['Winning Party'].value_counts()
purity       = seat_counts.max() / seat_counts.sum()

print("Seats by party:\n", seat_counts)
print(f"Purity = {purity:.1%}")
# Out:
# Seats by party:
#  Winning Party
# Labour              13
# Conservative         3
# Liberal Democrat     1
# Name: count, dtype: int64
# Purity = 76.5%

# %%
feature_cols = features.columns #the features in the dataset
valley_features = normalized_df.loc[valley_df.index, feature_cols]

# mean of the observations  education level inside the valley
valley_profile = valley_features.mean()

print(valley_features)
print(valley_profile)
# Out:
#      Over 0.5 and up to 1.0 people per room  \
# 32                                -0.069547
# 42                                 0.070603
# 94                                 0.076376
# 124                               -0.038469
# 178                                0.124161
# 187                               -0.000411
# 190                                0.000740
# 196                                0.116093
# 211                                0.097935
# 260                                0.118695
# 294                               -0.000926
# 311                                0.090482
# 315                               -0.034372
# 326                                0.000000
# 333                                0.136895
# 343                                0.110755
# 349                                0.133543
#
#      Over 1.0 and up to 1.5 people per room  Over 1.5 people per room  \
# 32                                 0.065380                 -0.152544
# 42                                -0.013993                 -0.220674
# 94                                -0.141046                 -0.389787
# 124                               -0.167619                 -0.035096
# 178                               -0.140110                 -0.137901
# 187                               -0.121203                 -0.104734
# 190                               -0.237040                 -0.312100
# 196                               -0.310609                 -0.230473
# 211                               -0.135562                 -0.291983
# 260                               -0.088375                 -0.216132
# 294                               -0.250743                 -0.285714
# 311                               -0.264457                 -0.023615
# 315                                0.033340                 -0.186151
# 326                               -0.199329                 -0.212811
# 333                               -0.218992                 -0.207390
# 343                               -0.171846                 -0.095590
# 349                               -0.172565                 -0.344416
#
#      Up to and including 0.5 people per room
# 32                                  0.122354
# 42                                  0.114473
# 94                                  0.201999
# 124                                 0.186692
# 178                                 0.130594
# 187                                 0.165613
# 190                                 0.258002
# 196                                 0.226765
# 211                                 0.170847
# 260                                 0.126459
# 294                                 0.259183
# 311                                 0.174505
# 315                                 0.129023
# 326                                 0.221535
# 333                                 0.173957
# 343                                 0.141030
# 349                                 0.183366
# Over 0.5 and up to 1.0 people per room     0.054856
# Over 1.0 and up to 1.5 people per room    -0.149104
# Over 1.5 people per room                  -0.202771
# Up to and including 0.5 people per room    0.175670
# dtype: float64
